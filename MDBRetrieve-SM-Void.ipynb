# %%
# %pip install langchain pypdf pymongo langchain-openai tiktoken unstructured unstructured[local-inference] "unstructured[pdf]"
# Out:
# Requirement already satisfied: langchain in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: pypdf in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: pymongo in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (4.6.1)
# Requirement already satisfied: langchain-openai in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.0.3)
# Requirement already satisfied: tiktoken in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.5.2)
# Requirement already satisfied: unstructured in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.14 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (0.0.14)
# Requirement already satisfied: langchain-core<0.2,>=0.1.14 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (0.1.14)
# Requirement already satisfied: langsmith<0.0.84,>=0.0.83 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (0.0.83)
# Requirement already satisfied: numpy<2,>=1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (1.26.1)
# Requirement already satisfied: pydantic<3,>=1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pymongo) (2.5.0)
# Requirement already satisfied: openai<2.0.0,>=1.6.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain-openai) (1.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from tiktoken) (2023.12.25)
# Requirement already satisfied: chardet in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (5.1.0)
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: tabulate in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: emoji in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (2.10.0)
# Requirement already satisfied: python-iso639 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (2024.1.2)
# Requirement already satisfied: langdetect in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: rapidfuzz in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (3.6.1)
# Requirement already satisfied: backoff in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (4.8.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (0.15.5)
# Requirement already satisfied: wrapt in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.5.3)
# Requirement already satisfied: msg-parser in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: pikepdf in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (8.11.2)
# Requirement already satisfied: onnx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.13.1)
# Requirement already satisfied: markdown in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (3.5.2)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (3.2)
# Requirement already satisfied: openpyxl in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (3.1.2)
# Requirement already satisfied: unstructured-inference==0.7.23 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (0.7.23)
# Requirement already satisfied: pypandoc in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.12)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (0.3.12)
# Requirement already satisfied: python-pptx<=0.6.23 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (0.6.23)
# Requirement already satisfied: pdf2image in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.17.0)
# Requirement already satisfied: xlrd in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (2.0.1)
# Requirement already satisfied: python-docx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: pdfminer.six in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured[local-inference]) (20221105)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (0.3.4)
# Requirement already satisfied: python-multipart in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (0.0.6)
# Requirement already satisfied: huggingface-hub in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (0.20.3)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (4.8.1.78)
# Requirement already satisfied: onnxruntime<1.16 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (1.15.1)
# Requirement already satisfied: transformers>=4.25.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-inference==0.7.23->unstructured[local-inference]) (4.37.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.14->langchain) (4.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.14->langchain) (23.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openai<2.0.0,>=1.6.1->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openai<2.0.0,>=1.6.1->langchain-openai) (0.26.0)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openai<2.0.0,>=1.6.1->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openai<2.0.0,>=1.6.1->langchain-openai) (4.66.1)
# Requirement already satisfied: Pillow>=3.3.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-pptx<=0.6.23->unstructured[local-inference]) (10.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-pptx<=0.6.23->unstructured[local-inference]) (3.1.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (2.8.2)
# Requirement already satisfied: six>=1.16.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from unstructured-client>=0.15.1->unstructured) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from beautifulsoup4->unstructured) (2.5)
# Requirement already satisfied: olefile>=0.46 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from msg-parser->unstructured[local-inference]) (0.47)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: protobuf in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from onnx->unstructured[local-inference]) (4.24.4)
# Requirement already satisfied: et-xmlfile in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from openpyxl->unstructured[local-inference]) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas->unstructured[local-inference]) (2023.3.post1)
# Requirement already satisfied: cryptography>=36.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pdfminer.six->unstructured[local-inference]) (41.0.5)
# Requirement already satisfied: Deprecated in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pikepdf->unstructured[local-inference]) (1.2.14)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.14->langchain) (1.1.3)
# Requirement already satisfied: cffi>=1.12 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (1.16.0)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.6.1->langchain-openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.6.1->langchain-openai) (0.14.0)
# Requirement already satisfied: coloredlogs in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[local-inference]) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[local-inference]) (23.5.26)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[local-inference]) (1.12)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[local-inference]) (3.12.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[local-inference]) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->unstructured[local-inference]) (0.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub->unstructured-inference==0.7.23->unstructured[local-inference]) (2023.10.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (1.11.3)
# Requirement already satisfied: iopath in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.1.10)
# Requirement already satisfied: pdfplumber in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.10.3)
# Requirement already satisfied: pytesseract in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.3.10)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (2.0.1)
# Requirement already satisfied: torchvision in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.15.2)
# Requirement already satisfied: effdet in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.4.1)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[local-inference]) (2.21)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from coloredlogs->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[local-inference]) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.9.12)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (2.3.0)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (3.1.2)
# Requirement already satisfied: portalocker in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (4.26.0)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->onnxruntime<1.16->unstructured-inference==0.7.23->unstructured[local-inference]) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->unstructured[local-inference]) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %pip show langchain

from platform import python_version
print(python_version())
# Out:
# Name: langchain
# Version: 0.1.2
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages
# Requires: aiohttp, async-timeout, dataclasses-json, jsonpatch, langchain-community, langchain-core, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# 3.10.13

# %%
import json
import boto3
from botocore.exceptions import ClientError

def get_secret():

    secret_name = "hackathon"
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        # For a list of exceptions thrown, see
        # https://docs.aws.amazon.com/secretsmanager/latest/apireference/API_GetSecretValue.html
        raise e

    secret = json.loads(get_secret_value_response['SecretString'])
    print(secret)
    return secret

# %%
secret = get_secret()

openai_api_key = secret["OPENAI_API_KEY"]
os.environ['OPENAI_API_KEY'] = openai_api_key

MONGODB_ATLAS_CLUSTER_URI = secret["MONGODB_ATLAS_CLUSTER_URI_VOID"]
os.environ['MONGODB_ATLAS_CLUSTER_URI'] = MONGODB_ATLAS_CLUSTER_URI

MONGODB_ATLAS_CLUSTER_URI_VOID = secret["MONGODB_ATLAS_CLUSTER_URI_VOID"]
os.environ['MONGODB_ATLAS_CLUSTER_URI'] = MONGODB_ATLAS_CLUSTER_URI

langsmith_api_key = secret["LANGSMITH_API_KEY"]
os.environ['LANGSMITH_API_KEY'] = langsmith_api_key

# %%
from pymongo import MongoClient

# initialize MongoDB python client
client = MongoClient(MONGODB_ATLAS_CLUSTER_URI_VOID)

DB_NAME = "Void_DB"
COLLECTION_NAME = "Outages"
ATLAS_VECTOR_SEARCH_INDEX_NAME = "vector_index"

MONGODB_COLLECTION = client[DB_NAME][COLLECTION_NAME]

# %%
from langchain_community.vectorstores import MongoDBAtlasVectorSearch
from langchain_openai import OpenAIEmbeddings

vector_search = MongoDBAtlasVectorSearch.from_connection_string(
    MONGODB_ATLAS_CLUSTER_URI,
    DB_NAME + "." + COLLECTION_NAME,
    OpenAIEmbeddings(disallowed_special=()),
    index_name=ATLAS_VECTOR_SEARCH_INDEX_NAME,
)

# %% [markdown]
# #Pre-filtering with Similarity Search
# Atlas Vector Search supports pre-filtering using MQL Operators for filtering. Below is an example index and query on the same data loaded above that allows you do metadata filtering on the “page” field. You can update your existing index with the filter defined and do pre-filtering with vector search.
#
# Use:
#
# ~~~
# {
#   "name": "index_name",
#   "type": "vectorSearch",
#   "fields":[
#     {
#       "type": "vector",
#       "path": "embedding",
#       "numDimensions": 1536,
#       "similarity": "cosine"
#     },
#     {
#       "type": "filter",
#       "path": "page"
#     }
#   ]
# }
# ~~~

# %%
#Don't run withput adding the filers in in the index JSON
query = "Summarize the outages"

results = vector_search.similarity_search_with_score(
    query=query, k=5, pre_filter={"page": {"$eq": 1}}
)

# Display results
for result in results:
    print(result)

# %% [markdown]
# #Similarity Search with Score

# %%
query = "What are the worst outages of 2023?"

results = vector_search.similarity_search_with_score(
    query=query,
    k=5,
)

# Display results
for result in results:
    print(result)
# Out:
# (Document(page_content='reportedly unusable.\n\nWe will update this story as we learn more.\n\nSubscribe to our daily newsletters\n\nEmail:\n\nCountry:\n\nSelect...\n\nI have read and agree to the Terms and Conditions and Privacy Policy\n\nYes, I agree\n\nSubmit\n\nMore in Outages\n\n10 Nov 2023\n\n16 Jan 2024\n\nWhy you need a Digital Twin of your Data Centers\n\nWidespread Verizon outage impacts North America\n\n"Critical incident" resolved as IT back online at Sussex hospital in UK\n\nTags\n\nAWS AWS Lamba Amazon Web Services\n\n0 Comments\n\n\ue6031 Login\n\nStart the discussion…\n\nLOG IN WITH\n\nOR SIGN UP WITH DISQUS\n\n?
.02174981411165697, 0.010217835666101419, -0.013798507566171979, -0.018383244899451114, 0.026962091525784177, 0.005780755342878585, -0.0047287021148182725, -0.007345914713465518, 0.011266197596967183, 0.03573289305681465, 0.009641974677299634, -0.027685608127658336, -0.007190875574681429, 0.007475114306226465, -0.007796267406700903, -0.017453008204101346, 0.013791124971782883, -0.008519784939897681, 0.008379510989891783, 0.023521692644396897, -0.0024510993354488588, -0.012846122156332306, 0.007449274760203323, -0.026740606243530377, -0.01094873579368729, -0.010291663472637606, -0.0013418291382278234, -0.0035160723365207417, -0.0001534244145402129, 0.02897022052955609, 0.006637163300369548, 0.008098963089879986, -0.025426463464076243, 0.01086752446143939, -0.006471049804340508, -0.006544878076538005, -0.009892991268432431, 0.0059653257905416725, 0.0063603071632136075, 0.03425632575021948, -8.732502867445457e-05, -0.026371465348204202, 0.023182083989272337, 0.018191289994753695, 0.004558896855933376, 0.02152832882940317, 0.007899627453438708, -0.02617951230615202, -0.00020533494025695172, 0.012026629033432054, 0.020347076474243223, 0.010963500982465482, 0.012299793407732138, 0.013732062354024886, 0.01568112967136142, -0.01897387107703109, 0.02101153232100462, -0.0162126932311834, -0.018840980652736903, -0.0006907559318189048, -0.005245500020200751, -0.0029291374561353145, -0.01397569541944597, -0.021336375787350988, -0.007604313898987411, 0.0060096227538601705, -0.0007673527933276397, 0.0004817295925039942, 0.007781501752261404, -0.007751970443382405, 0.027242639425795974, 0.003868602394471453, -0.0004812681803546757, -0.004293115076022387, -0.01020306954600061, 0.020509499138739024, 0.006131439752232022, 0.005378390910156245, -0.04571447732056146, 0.026430527965962198, 0.01804363438168132, 0.02684396629026818, 0.005330402649643199, 0.02877826748750391, 0.0009726877190326755, -0.010151389522631707, -0.0157106600489178, -0.014839486902648647, -0.002043197956934698, 0.0024843219415224055, 0.020273248667707033, 7.4520434077222 ...

# %% [markdown]
# #Question Answering

# %%
qa_retriever = vector_search.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 15},
)

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
from langchain.chains import RetrievalQA
from langchain_openai import OpenAI

qa = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=qa_retriever,
    return_source_documents="True",
    chain_type_kwargs={"prompt": PROMPT},
)

docs = qa({"query": "What companies had outages in 2023"})

print(docs["result"])
#print(docs["source_documents"])
# Out:
# Some companies that experienced outages in 2023 include:
#
# 1. Amazon Web Services (AWS)
#
# 2. Cloudflare
#
# 3. Twitter
#
# 4. Stack Exchange Network
#
# 5. Burger King
#
# 6. The Associated Press
#
# 7. PlutoTV
#
# 8. Hinge
#
# 9. Delta
#
# 10. Goodreads

# %%
qa_retriever = vector_search.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 15},
)

# %%
from langchain.prompts import PromptTemplate

prompt_template = """Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.

{context}

Question: {question}
"""
PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)

# %%
from langchain.chains import RetrievalQA
from langchain_openai import OpenAI

qa = RetrievalQA.from_chain_type(
    llm=OpenAI(),
    chain_type="stuff",
    retriever=qa_retriever,
    return_source_documents="True",
    chain_type_kwargs={"prompt": PROMPT},
)

docs = qa({"query": "What is Profound Knowledge?"})

print(docs["result"])
#print(docs["source_documents"])
